# %%
import pandas as pd

# %%
col = ['State', 'ST', 'Fips', 'County',
    'Republicans 2016', 'Democrats 2016',
    'Republicans 2012','Democrats 2012', 
    'Republicans 2008', 'Democrats 2008']
df = pd.read_csv('../Data/Politics/formatted-usa-2016-presidential-election-by-county.csv', usecols=col)
df.head(3)
# Out:
#       State  ST   Fips                    County  Republicans 2016  \
# 0  Arkansas  AR   5087  Madison County, Arkansas         72.001757
# 1    Oregon  OR  41029    Jackson County, Oregon         51.145112
# 2     Maine  ME  23025    Somerset County, Maine         57.755699
#
#    Democrats 2016  Republicans 2012  Republicans 2008  Democrats 2012  \
# 0       23.239127         64.905603         62.768647       31.957978
# 1       41.960131         50.470003         48.534840       45.783356
# 2       35.012323         47.605600         46.071124       49.283899
#
#    Democrats 2008
# 0       33.881163
# 1       48.581353
# 2       51.770324

# %%
df['2016']=pd.qcut(df['Republicans 2016'], 10, labels=[i for i in range(1,11)], duplicates='drop', )
df['2012']=pd.qcut(df['Republicans 2012'], 10, labels=[i for i in range(1,11)], duplicates='drop', )
df['2008']=pd.qcut(df['Republicans 2008'], 10, labels=[i for i in range(1,11)], duplicates='drop', )
df.head(3)
# Out:
#       State  ST   Fips                    County  Republicans 2016  \
# 0  Arkansas  AR   5087  Madison County, Arkansas         72.001757
# 1    Oregon  OR  41029    Jackson County, Oregon         51.145112
# 2     Maine  ME  23025    Somerset County, Maine         57.755699
#
#    Democrats 2016  Republicans 2012  Republicans 2008  Democrats 2012  \
# 0       23.239127         64.905603         62.768647       31.957978
# 1       41.960131         50.470003         48.534840       45.783356
# 2       35.012323         47.605600         46.071124       49.283899
#
#    Democrats 2008 2016 2012 2008
# 0       33.881163    7    7    7
# 1       48.581353    3    3    3
# 2       51.770324    4    2    3

# %%
df['party'] = [(row[-4]*10 + row[-3]*4 + row[-2]*3)/17 for i, row in df.iterrows()]
df.head(3)
# Out:
#       State  ST   Fips                    County  Republicans 2016  \
# 0  Arkansas  AR   5087  Madison County, Arkansas         72.001757
# 1    Oregon  OR  41029    Jackson County, Oregon         51.145112
# 2     Maine  ME  23025    Somerset County, Maine         57.755699
#
#    Democrats 2016  Republicans 2012  Republicans 2008  Democrats 2012  \
# 0       23.239127         64.905603         62.768647       31.957978
# 1       41.960131         50.470003         48.534840       45.783356
# 2       35.012323         47.605600         46.071124       49.283899
#
#    Democrats 2008 2016 2012 2008      party
# 0       33.881163    7    7    7  22.812449
# 1       48.581353    3    3    3  29.812561
# 2       51.770324    4    2    3  31.747249

# %%
df[df['party'] < 3]
# Out:
# Empty DataFrame
# Columns: [State, ST, Fips, County, Republicans 2016, Democrats 2016, Republicans 2012, Republicans 2008, Democrats 2012, Democrats 2008, 2016, 2012, 2008, party]
# Index: []

# %%
df2 = pd.DataFrame(df['Fips'])
df2['political_party'] = df['party']
df2.to_csv('../Data/Cleaned/Political_raw.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _ensure_valid_index(self, value)
#    3053             try:
# -> 3054                 value = Series(value)
#    3055             except (ValueError, NotImplementedError, TypeError):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     201
# --> 202             if is_empty_data(data) and dtype is None:
#     203                 # gh-17261
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in is_empty_data(data)
#     585     is_list_like_without_dtype = is_list_like(data) and not hasattr(data, "dtype")
# --> 586     is_simple_empty = is_list_like_without_dtype and not data
#     587     return is_none or is_simple_empty
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-0c4666f8acdd> in <module>
#       1 df2=pd.DataFrame()
# ----> 2 df2["FIPS"] = pd.DataFrame(df['Fips'])
#       3 df2['political_party'] = df['party']
#       4 df2.to_csv('../Data/Cleaned/Political_raw.csv')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2997         """
#    2998
# -> 2999         self._ensure_valid_index(value)
#    3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _ensure_valid_index(self, value)
#    3055             except (ValueError, NotImplementedError, TypeError):
#    3056                 raise ValueError(
# -> 3057                     "Cannot set a frame with no defined index "
#    3058                     "and a value that cannot be converted to a "
#    3059                     "Series"
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series
