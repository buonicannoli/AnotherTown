# %%
import pandas as pd

# %%
cols = ['GEO_ID','Geographic Area Name','S1501_C02_012E']
df = pd.read_csv('../Data/Education/Educational Attainment/Education_Attainment.csv', usecols = cols)
df.head(3)
# Out:
#            GEO_ID                       NAME  \
# 0              id       Geographic Area Name
# 1  0500000US01117     Shelby County, Alabama
# 2  0500000US01121  Talladega County, Alabama
#
#                                S1501_C01_001E  \
# 0  Estimate!!Total!!Population 18 to 24 years
# 1                                       17648
# 2                                        6743
#
#                                       S1501_C01_001M  \
# 0  Margin of Error!!Total MOE!!Population 18 to 2...
# 1                                                776
# 2                                                138
#
#                                  S1501_C02_001E  \
# 0  Estimate!!Percent!!Population 18 to 24 years
# 1                                           (X)
# 2                                           (X)
#
#                                       S1501_C02_001M  \
# 0  Margin of Error!!Percent MOE!!Population 18 to...
# 1                                                (X)
# ...

# %%
cols = ['FIPS Code', 'State', 'Area name', "adults_bs_2014-18"]
df = pd.read_csv('../Data/Education/Educational Attainment/Education_data.csv', usecols = cols, encoding='iso-8859-1' )

# %%
df.head()
# Out:
#    FIPS Code State       Area name  adults_bs_2014-18
# 0          0    US   United States               31.5
# 1       1000    AL         Alabama               24.9
# 2       1001    AL  Autauga County               27.7
# 3       1003    AL  Baldwin County               31.3
# 4       1005    AL  Barbour County               12.2

# %%
df.to_csv('../Data/Cleaned/Eduction_Educational_Attainment.csv')
