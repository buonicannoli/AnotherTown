# %%
import pandas as pd

# %%
pd.read_csv('../Data/Education/graduation_rates.csv')
# Out:
#          STNAM  FIPST    LEAID    ST_LEAID  \
# 0      ALABAMA      1   100005      AL-101
# 1      ALABAMA      1   100006      AL-048
# 2      ALABAMA      1   100007      AL-158
# 3      ALABAMA      1   100008      AL-169
# 4      ALABAMA      1   100011      AL-167
# ...        ...    ...      ...         ...
# 12307  WYOMING     56  5605762  WY-1902000
# 12308  WYOMING     56  5605820  WY-2202000
# 12309  WYOMING     56  5605830  WY-2001000
# 12310  WYOMING     56  5606090  WY-2307000
# 12311  WYOMING     56  5606240  WY-2201000
#
#                                       LEANM  ALL_COHORT_1718 ALL_RATE_1718  \
# 0                          Albertville City              312            94
# 1                           Marshall County              416            91
# 2                               Hoover City             1120            94
# 3                              Madison City              923            96
# ...
